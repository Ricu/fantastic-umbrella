# %%
import os
from pathlib import Path
import fnmatch
import json
import pandas as pd
import re

# %%
# for path,dirs,files in os.walk('.\\runs'):
#     for file in fnmatch.filter(files,'all_results.json'):
#         fullname = os.path.abspath(os.path.join(path,file))
        
#         task_name = os.path.basename(path)
#         folder_str = os.path.basename(os.path.dirname(os.path.dirname(fullname))) # move up two folders and get folder name
#         arguments = {}
#         if 'mod' in folder_str:
#             arguments['modded'] = True
#         else:
#             arguments['modded'] = False

#         rr = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", folder_str)
#         arguments["num_train_epochs"] = int(rr[1])
#         arguments["hidden_dropout"] = float(rr[0])

#         # print(arguments)
#         with open(os.path.abspath(os.path.join(path,'used_arguments.json')), "w") as f: 
#             json.dump(arguments,f)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 14
#      11     arguments['modded'] = False
#      13 rr = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", folder_str)
# ---> 14 arguments["num_train_epochs"] = int(rr[1])
#      15 arguments["hidden_dropout"] = float(rr[0])
#      17 # print(arguments)
#
# IndexError: list index out of range

# %%
series_list = []
for path,dirs,files in os.walk('.\\finished_runs'):
    for file in fnmatch.filter(files,'used_arguments.json'):
        with open(os.path.abspath(os.path.join(path,file))) as f:
            d = json.load(f)
            series_list.append(d)
            break

df = pd.DataFrame(series_list)
df
# Out:
#     task_name train_file validation_file  max_length  pad_to_max_length  \
# 0        wnli       None            None         128              False
# 1        wnli       None            None         128              False
# 2        wnli       None            None         128              False
# 3        wnli       None            None         128              False
# 4        wnli       None            None         128              False
# ..        ...        ...             ...         ...                ...
# 427       rte       None            None         128              False
# 428       rte       None            None         128              False
# 429       rte       None            None         128              False
# 430       rte       None            None         128              False
# 431       rte       None            None         128              False
#
#     model_name_or_path  use_slow_tokenizer  per_device_train_batch_size  \
# 0      bert-base-cased               False                           32
# 1      bert-base-cased               False                           32
# 2      bert-base-cased               False                           32
# 3      bert-base-cased               False                           32
# 4      bert-base-cased               False                           32
# ..                 ...                 ...                          ...
# 427    bert-base-cased               False                           32
# 428    bert-base-cased               False                           32
# 429    bert-base-cased               False                           32
# 430    bert-base-cased               False                           32
# 431    bert-base-cased               False                           32
#
#      per_device_eval_batch_size  learning_rate  ...  checkpointing_steps  \
# 0                             8        0.00005  ...                 None
# 1                             8        0.00005  ...                 None
# 2                             8        0.00005  ...                 None
# 3                             8        0.00005  ...                 None
# 4                             8        0.00005  ...                 None
# ..                          ...            ...  ...                  ...
# 427                           8        0.00001  ...                 None
# 428                           8        0.00001  ...                 None
# 429                           8        0.00001  ...                 None
# 430                           8        0.00001  ...                 None
# 431                           8        0.00001  ...                 None
#
#      resume_from_checkpoint  with_tracking    report_to  \
# 0                      None           True  tensorboard
# 1                      None           True  tensorboard
# 2                      None           True  tensorboard
# 3                      None           True  tensorboard
# 4                      None           True  tensorboard
# ..                      ...            ...          ...
# 427                    None           True  tensorboard
# 428                    None           True  tensorboard
# 429                    None           True  tensorboard
# 430                    None           True  tensorboard
# 431                    None           True  tensorboard
#
#     ignore_mismatched_sizes  hidden_dropout train_data_frac  \
# 0                     False             0.1             1.0
# 1                     False             0.1             1.0
# 2                     False             0.1             1.0
# 3                     False             0.1             1.0
# 4                     False             0.1             1.0
# ..                      ...             ...             ...
# 427                   False             0.8             0.1
# 428                   False             0.8             0.1
# 429                   False             0.8             0.1
# 430                   False             0.8             0.1
# 431                   False             0.8             0.1
#
#      use_pretrain_dropout_in_first_pass  use_modded eval_accuracy
# 0                                  True        True      0.436620
# 1                                  True        True      0.281690
# 2                                  True        True      0.112676
# 3                                  True       False      0.549296
# 4                                  True       False      0.464789
# ..                                  ...         ...           ...
# 427                               False        True      0.451264
# 428                               False        True      0.451264
# 429                               False       False      0.454874
# 430                               False       False      0.451264
# 431                               False       False      0.472924
#
# [432 rows x 31 columns]

# %%
keep = [c for c in list(df) if len(df[c].unique()) > 1]
df_small = df[keep]#.drop(["output_dir"],axis=1)
df_small
# Out:
#                                           output_dir  \
# 0  /content/drive/MyDrive/Masterarbeit/fantastic-...
# 1  /content/drive/MyDrive/Masterarbeit/fantastic-...
# 2  /content/drive/MyDrive/Masterarbeit/fantastic-...
#
#    use_pretrain_dropout_in_first_pass  use_modded  eval_accuracy
# 0                                True        True       0.464789
# 1                                True       False       0.380282
# 2                               False        True       0.408451

# %%
df_small.to_csv(".\\runs\\summary.csv")

# %%
import seaborn as sns
# sns.set_theme(style="ticks", palette="pastel")

# df_plot = df_small
df_plot = df_small.loc[df_small["task_name"]=="wnli",]

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="hidden_dropout", y="eval_accuracy",
            hue="use_modded",
            data=df_plot)
# sns.despine(offset=10, trim=True)
# Out:
# <Axes: xlabel='hidden_dropout', ylabel='eval_accuracy'>

# %%
acc_diff = df_small.loc[df_small["use_modded"],"eval_accuracy"].reset_index(drop=True)-df_small.loc[~df_small["use_modded"],"eval_accuracy"].reset_index(drop=True)

df_diff = df_small.loc[df_small["use_modded"],].drop(["eval_accuracy","use_modded"], axis=1).reset_index(drop=True)
df_diff["mod_better"] = acc_diff.apply(lambda x: 1 if x>0 else (0 if x<0 else 0.5))
df_diff["accuracy_diff"] = acc_diff
df_diff
# Out:
#     task_name  learning_rate  num_train_epochs  hidden_dropout  \
# 0        wnli        0.00005                 5             0.1
# 1        wnli        0.00005                10             0.1
# 2        wnli        0.00005                20             0.1
# 3        wnli        0.00005                 5             0.1
# 4        wnli        0.00005                10             0.1
# ..        ...            ...               ...             ...
# 211       rte        0.00001                10             0.8
# 212       rte        0.00001                20             0.8
# 213       rte        0.00001                 5             0.8
# 214       rte        0.00001                10             0.8
# 215       rte        0.00001                20             0.8
#
#      train_data_frac  use_pretrain_dropout_in_first_pass  mod_better  \
# 0                1.0                                True         0.0
# 1                1.0                                True         0.0
# 2                1.0                                True         0.5
# 3                0.5                                True         1.0
# 4                0.5                                True         0.0
# ..               ...                                 ...         ...
# 211              0.5                               False         0.0
# 212              0.5                               False         1.0
# 213              0.1                               False         0.0
# 214              0.1                               False         0.5
# 215              0.1                               False         0.0
#
#      accuracy_diff
# 0        -0.112676
# 1        -0.183099
# 2         0.000000
# 3         0.028169
# 4        -0.028169
# ..             ...
# 211      -0.010830
# 212       0.003610
# 213      -0.010830
# 214       0.000000
# 215      -0.021661
#
# [216 rows x 8 columns]

# %%
df_diff.hist()
# Out:
# array([[<Axes: title={'center': 'learning_rate'}>,
#         <Axes: title={'center': 'num_train_epochs'}>],
#        [<Axes: title={'center': 'hidden_dropout'}>,
#         <Axes: title={'center': 'train_data_frac'}>],
#        [<Axes: title={'center': 'mod_better'}>,
#         <Axes: title={'center': 'accuracy_diff'}>]], dtype=object)

# %%
# Out:
# 6

# %%
import matplotlib.pyplot as plt
import math
fig, axs = plt.subplots(math.ceil(len(df_diff.columns.drop(["mod_better","accuracy_diff"]))/2),2)
for idx,ax in enumerate(axs.reshape(-1)):
    col = df_diff.columns.drop("accuracy_diff")[idx]
    df_diff.loc[df_diff["mod_better"]==1,col].value_counts().plot.bar(ax=ax)
    ax.set_title(col)

fig.tight_layout()

# %%
df_diff.loc[df_diff["mod_better"]==1,"use_pretrain_dropout_in_first_pass"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_diff["accuracy_diff"].hist(bins = 50)
# Out:
# <Axes: >

# %%
sns.boxplot(x="mod_better", y="accuracy_diff",
            data=df_diff)
# Out:
# <Axes: xlabel='mod_better', ylabel='accuracy_diff'>

# %%
import dtale

dtale.show(df_small)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-HFP2417:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2023-07-12 17:13:48,357 - INFO     - Executing shutdown due to inactivity...
# 2023-07-12 17:14:00,560 - INFO     - Executing shutdown...
# 2023-07-12 17:14:00,562 - ERROR    - Exception on /shutdown [GET]
# Traceback (most recent call last):
#   File "c:\Users\Valentin\miniconda3\envs\fantastic-umbrella\lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Valentin\miniconda3\envs\fantastic-umbrella\lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Valentin\miniconda3\envs\fantastic-umbrella\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Valentin\miniconda3\envs\fantastic-umbrella\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "c:\Users\Valentin\miniconda3\envs\fantastic-umbrella\lib\site-packages\dtale\app.py", line 438, in shutdown
#     shutdown_server()
#   File "c:\Users\Valentin\miniconda3\envs\fantastic-umbrella\lib\site-packages\dtale\app.py", line 424, in shutdown_server
#     raise RuntimeError("Not running with the Werkzeug Server")
# RuntimeError: Not running with the Werkzeug Server

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

# %%
event_acc = EventAccumulator('G:\\Meine Ablage\\Masterarbeit\\fantastic-umbrella\\finished_runs\\02_reference_runs\\run_reference_0_\\glue_no_trainer')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': [], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
